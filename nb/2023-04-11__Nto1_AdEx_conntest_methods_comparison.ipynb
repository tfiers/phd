# %% [markdown]
# # 2023-04-11 • Nto1 AdEx sims: conntest method comparison

# %% [markdown]
# Data generated in `2023-02-24__multisim-winline.jl`

# %%
using CSV

# %%
using DataFrames

# %%
df = CSV.read("../data/Nto1_AdEx.csv", DataFrame)
# Out:
# 90×13 DataFrame
#  Row │ N      Nᵤ     δ_nS     duration  seed   method          TPRₑ        TPR ⋯
#      │ Int64  Int64  Float64  Float64   Int64  String15        Float64     Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     5    100     5.0      600.0      1  STA_corr_2pass  1.0         1.0 ⋯
#    2 │     5    100     5.0      600.0      1  STA_height      1.0         1.0
#    3 │     5    100     5.0      600.0      1  fit_upstroke    1.0         1.0
#    4 │     5    100     5.0      600.0      2  fit_upstroke    1.0         1.0
#    5 │     5    100     5.0      600.0      2  STA_corr_2pass  1.0         1.0 ⋯
#    6 │     5    100     5.0      600.0      2  STA_height      1.0         1.0
#    7 │     5    100     5.0      600.0      3  fit_upstroke    1.0         1.0
#    8 │     5    100     5.0      600.0      3  STA_corr_2pass  1.0         1.0
#    9 │     5    100     5.0      600.0      3  STA_height      1.0         1.0 ⋯
#   10 │     5    100     5.0      600.0      4  STA_corr_2pass  1.0         1.0
#   11 │     5    100     5.0      600.0      4  fit_upstroke    1.0         1.0
#   ⋮  │   ⋮      ⋮       ⋮        ⋮        ⋮          ⋮             ⋮           ⋱
#   81 │  6500    100     0.02     600.0      2  STA_corr_2pass  0.00961538  0.0
#   82 │  6500    100     0.02     600.0      3  STA_height      0.0188462   0.0 ⋯
#   83 │  6500    100     0.02     600.0      3  STA_corr_2pass  0.00480769  0.0
#   84 │  6500    100     0.02     600.0      3  fit_upstroke    0.101538    0.2
#   85 │  6500    100     0.02     600.0      4  fit_upstroke    0.151154    0.2
#   86 │  6500    100     0.02     600.0      4  STA_height      0.0157692   0.0 ⋯
#   87 │  6500    100     0.02     600.0      4  STA_corr_2pass  0.00692308  0.0
#   88 │  6500    100     0.02     600.0      5  STA_height      0.0326923   0.0
#   89 │  6500    100     0.02     600.0      5  STA_corr_2pass  0.00730769  0.0
#   90 │  6500    100     0.02     600.0      5  fit_upstroke    0.0732692   0.1 ⋯
#                                                    6 columns and 69 rows omitted

# %%
df[df.N .== 6500, :]
# Out:
# 15×13 DataFrame
#  Row │ N      Nᵤ     δ_nS     duration  seed   method          TPRₑ        TPR ⋯
#      │ Int64  Int64  Float64  Float64   Int64  String15        Float64     Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  6500    100     0.02     600.0      1  STA_corr_2pass  0.00769231  0.0 ⋯
#    2 │  6500    100     0.02     600.0      1  fit_upstroke    0.0655769   0.1
#    3 │  6500    100     0.02     600.0      1  STA_height      0.0265385   0.0
#    4 │  6500    100     0.02     600.0      2  fit_upstroke    0.0338462   0.1
#    5 │  6500    100     0.02     600.0      2  STA_height      0.0188462   0.0 ⋯
#    6 │  6500    100     0.02     600.0      2  STA_corr_2pass  0.00961538  0.0
#    7 │  6500    100     0.02     600.0      3  STA_height      0.0188462   0.0
#    8 │  6500    100     0.02     600.0      3  STA_corr_2pass  0.00480769  0.0
#    9 │  6500    100     0.02     600.0      3  fit_upstroke    0.101538    0.2 ⋯
#   10 │  6500    100     0.02     600.0      4  fit_upstroke    0.151154    0.2
#   11 │  6500    100     0.02     600.0      4  STA_height      0.0157692   0.0
#   12 │  6500    100     0.02     600.0      4  STA_corr_2pass  0.00692308  0.0
#   13 │  6500    100     0.02     600.0      5  STA_height      0.0326923   0.0 ⋯
#   14 │  6500    100     0.02     600.0      5  STA_corr_2pass  0.00730769  0.0
#   15 │  6500    100     0.02     600.0      5  fit_upstroke    0.0732692   0.1
#                                                                6 columns omitted

# %%
df2 = groupby(df, [:method, :N])
# Out:
# GroupedDataFrame with 18 groups based on keys: method, N
# First Group (5 rows): method = "STA_corr_2pass", N = 5
#  Row │ N      Nᵤ     δ_nS     duration  seed   method          TPRₑ     TPRᵢ   ⋯
#      │ Int64  Int64  Float64  Float64   Int64  String15        Float64  Float6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     5    100      5.0     600.0      1  STA_corr_2pass      1.0      1. ⋯
#    2 │     5    100      5.0     600.0      2  STA_corr_2pass      1.0      1.
#   ⋮  │   ⋮      ⋮       ⋮        ⋮        ⋮          ⋮            ⋮        ⋮   ⋱
#    5 │     5    100      5.0     600.0      5  STA_corr_2pass      1.0      1.
#                                                     6 columns and 2 rows omitted
# ⋮
# Last Group (5 rows): method = "STA_height", N = 6500
#  Row │ N      Nᵤ     δ_nS     duration  seed   method      TPRₑ       TPRᵢ     ⋯
#      │ Int64  Int64  Float64  Float64   Int64  String15    Float64    Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  6500    100     0.02     600.0      1  STA_height  0.0265385  0.068461 ⋯
#    2 │  6500    100     0.02     600.0      2  STA_height  0.0188462  0.044615
#   ⋮  │   ⋮      ⋮       ⋮        ⋮        ⋮        ⋮           ⋮          ⋮    ⋱
#    5 │  6500    100     0.02     600.0      5  STA_height  0.0326923  0.066923
#                                                     6 columns and 2 rows omitted

# %%
using Statistics

# %%
dfm = sort!(combine(df2, Between(:TPRₑ, :AUCᵢ) .=> mean), :N)
# Out:
# 18×9 DataFrame
#  Row │ method          N      TPRₑ_mean   TPRᵢ_mean   TPR_mean    FPR_mean  AU ⋯
#      │ String15        Int64  Float64     Float64     Float64     Float64   Fl ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ STA_corr_2pass      5  1.0         1.0         1.0            0.052  0. ⋯
#    2 │ STA_height          5  1.0         1.0         1.0            0.054  0.
#    3 │ fit_upstroke        5  1.0         1.0         1.0            0.05   1.
#    4 │ STA_corr_2pass     20  1.0         1.0         1.0            0.052  0.
#    5 │ STA_height         20  0.9         1.0         0.92           0.056  0. ⋯
#    6 │ fit_upstroke       20  1.0         1.0         1.0            0.05   1.
#    7 │ fit_upstroke      100  0.8025      0.84        0.81           0.05   0.
#    8 │ STA_height        100  0.61        0.7         0.628          0.04   0.
#    9 │ STA_corr_2pass    100  0.8         0.8         0.8            0.04   0. ⋯
#   10 │ fit_upstroke      400  0.951875    0.995       0.9605         0.05   0.
#   11 │ STA_height        400  0.518125    0.63        0.5405         0.052  0.
#   12 │ STA_corr_2pass    400  0.958125    0.9975      0.966          0.05   0.
#   13 │ STA_corr_2pass   1600  0.00015625  0.0         0.000125       0.054  0. ⋯
#   14 │ fit_upstroke     1600  0.431719    0.81125     0.507625       0.05   0.
#   15 │ STA_height       1600  0.1575      0.381875    0.202375       0.054  0.
#   16 │ STA_corr_2pass   6500  0.00726923  0.00138462  0.00609231     0.05   0.
#   17 │ fit_upstroke     6500  0.0850769   0.183231    0.104708       0.05   0. ⋯
#   18 │ STA_height       6500  0.0225385   0.0553846   0.0291077      0.048  0.
#                                                                3 columns omitted

# %%
using WithFeedback

# %%
@withfb using PyPlot      # mpl wrapper
@withfb using Sciplotlib  # pyplot wrapper
@withfb using PhDPlots    # local plotting funcs
# Out:
# using PyPlot … ✔
# using Sciplotlib … ✔
# using PhDPlots … ✔

# %%
function plotrates(m)

    df3 = df[df.method .== m, :]
    df3m = dfm[dfm.method .== m, :]

    # jitter(x) = x .* (0.95 .+ 0.1.*rand(length(x)))
    jitter(x) = x

    fig, ax = plt.subplots()
    clip_on = false
    plt.semilogx(jitter(df3.N), df3.TPR, ".", ms = 8; clip_on)
    plt.semilogx(jitter(df3m.N), df3m.TPR_mean, "C0-"; clip_on)
    plt.semilogx(jitter(df3.N), df3.FPR, ".", ms = 3; clip_on)

    Ns = unique(df.N)

    plt.xticks(Ns, Ns)
    plt.minorticks_off()

    plt.ylabel("Detection rate")
    plt.xlabel("Number of inputs (N)")
    plt.title(m)
end

plotrates("fit_upstroke")
plotrates("STA_height")
plotrates("STA_corr_2pass")
;
# Out:
# Figure(PyObject <Figure size 800x480 with 1 Axes>)
# Figure(PyObject <Figure size 800x480 with 1 Axes>)
# Figure(PyObject <Figure size 800x480 with 1 Axes>)

# %% [markdown]
# ## What's up with that N=100, zero detections point

# %% [markdown]
# Which seed is it?

# %%
df[df.N .== 100 .&& df.seed .== 1, :]
# Out:
# 3×13 DataFrame
#  Row │ N      Nᵤ     δ_nS     duration  seed   method          TPRₑ     TPRᵢ   ⋯
#      │ Int64  Int64  Float64  Float64   Int64  String15        Float64  Float6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   100    100     0.75     600.0      1  fit_upstroke     0.0125      0. ⋯
#    2 │   100    100     0.75     600.0      1  STA_height       0.0         0.
#    3 │   100    100     0.75     600.0      1  STA_corr_2pass   0.0         0.
#                                                                6 columns omitted

# %% [markdown]
# First let's inspect the simulation

# %%
include("2023-03-14__[setup]_Nto1_sim_AdEx.jl");
# Out:
# using Distributed … ✔
# using Revise … ✔ (0.6 s)
# using SpikeWorks … ✔ (1.2 s)
# using SpikeWorks.Units … ✔ (0.9 s)
# using ConnectionTests … ✔
# using DataFrames … ✔ (1.7 s)
# using MemDiskCache … ✔ (0.9 s)

# %%
sd = sims(; N=100, seed=1, duration=10minutes, δ_nS=0.75);

# %%
plotsig(voltsig(sd) / mV, [0,500], ms, hylabel = "Simulated membrane voltage (mV)");
# Out:
# Figure(PyObject <Figure size 800x480 with 1 Axes>)

# %% [markdown]
# We need to fix the spike peaks for aesthetics. But otherwise seems fine.

# %%
spikerate(sd) / Hz
# Out:
# 8.856666667832444

# %% [markdown]
# Maybe sth went wrong during calc and wrong data was saved.
# Otoh, both the STA methods and the upstroke fit (which uses the sim directly) have bad perf..

# %% [markdown]
# Ok but first, is this very different from another seed?

# %%
sd2 = sims(; N=100, seed=2, duration=10minutes, δ_nS=0.75);
# Out:
# Loading [/root/.julia/MemDiskCache.jl/2023-03-14__Nto1_AdEx/run_sim/_  N=100  δ_nS=0.75  duration=600.0  seed=2  _.jld2] … ✔ (1.9 s)

# %%
plotsig(voltsig(sd2) / mV, [0,500], ms, hylabel = "Simulated membrane voltage (mV)", ylim=[-80, 0]);
# Out:
# Figure(PyObject <Figure size 800x480 with 1 Axes>)

# %% [markdown]
# So no, looks similar.

# %% [markdown]
# Let's then look at some STAs.

# %%
kw = (; N=100, duration=10minutes, δ_nS=0.75, Nᵤ=100, batch_size, part=1);

# %%
reals, shufs = STA_sets(; kw..., seed=1);
# Out:
# Loading [/root/.julia/MemDiskCache.jl/2023-03-14__Nto1_AdEx/calc_all_STAs/_  N=100  Nᵤ=100  δ_nS=0.75  duration=600.0  seed=1  batch_size=300  part=1  _.jld2] … ✔ (0.3 s)

# %%
ylim = [-59, -56]
plotSTA(reals[1]; ylim);
# Out:
# Figure(PyObject <Figure size 800x480 with 1 Axes>)

# %% [markdown]
# Seems proper

# %%
reals2, shufs2 = STA_sets(; kw..., seed=2);
plotSTA(reals2[1]; ylim, color=C1);
# Out:
# Loading [/root/.julia/MemDiskCache.jl/2023-03-14__Nto1_AdEx/calc_all_STAs/_  N=100  Nᵤ=100  δ_nS=0.75  duration=600.0  seed=2  batch_size=300  part=1  _.jld2] … ✔ (0.2 s)
# Figure(PyObject <Figure size 800x480 with 1 Axes>)

# %% [markdown]
# Not too different.

# %%
plotSTA(shufs[1][1]; ylim);
plotSTA(shufs2[1][1]; ylim);
# Out:
# Figure(PyObject <Figure size 800x480 with 1 Axes>)

# %% [markdown]
# So only difference is a lower avg Vm.

# %%
mean(voltsig(sd)) / mV
# Out:
# -57.73967079215508

# %%
mean(voltsig(sd2)) / mV
# Out:
# -58.51984240174548

# %% [markdown]
# ---

# %% [markdown]
# Or maybe, let's delete the cached data and recalculate, see if it stays the same.

# %% [markdown]
# Nope, it stayed the same.

# %% [markdown]
# Huh!
