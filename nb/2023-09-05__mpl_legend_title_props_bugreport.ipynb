# %% [markdown]
# # 2023-09-05__mpl_legend_title_props_bugreport

# %%
import matplotlib.pyplot as plt

# %%
plt.matplotlib.__version__
# Out:
# '3.7.1'

# %%
fig, ax = plt.subplots()
ax.plot([1,2,1], label="line")
font = {"size": 20, "family": "monospace"}
ax.legend(title="Look:", prop=font, title_fontproperties=font)

# %% [markdown]
# Ah ok, it works here..
