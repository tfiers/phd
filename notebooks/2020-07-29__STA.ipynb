# %% [markdown]
# # 2020-07-29 • Spike-triggered averaging

# %%
# %run init.ipynb
# Out:
# Importing np, mpl, plt … ✔
# Importing unyt … ✔
# Importing code package (voltage_to_wiring_sim), as `v` … ✔
# Imported * from v.util and from v.units

# %%
fix_rng_seed()

# %%
RS = v.neuron_params.cortical_RS
sim = v.neuron_sim.simulate_izh_neuron
gen_st = v.presynaptic_spike_train.generate_spike_train

tg = v.time_grid.TimeGrid(T=10*min, dt=0.1*ms)

# %%
N_in = 200
p_connected = 0.5

N_connected = round(N_in * p_connected)
N_unconnected = N_in - N_connected

# %%
# %%time
sts_connected = gen_st(tg, f_spike=2*Hz)
# Out:
# Wall time: 154 ms

# %%
# %%time
out = sim(tg, RS)
# Out:
# Wall time: 520 ms

# %%
plt.plot(tg.t, out.V_m)
