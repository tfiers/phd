# %%
using DataFrames

# %%
df = DataFrame(x=[3,1,2])
# Out:
# 3×1 DataFrame
#  Row │ x
#      │ Int64
# ─────┼───────
#    1 │     3
#    2 │     1
#    3 │     2

# %%
using PyPlot

# %%
fig, ax = plt.subplots()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (Figure(PyObject <Figure size 640x480 with 1 Axes>), PyObject <AxesSubplot:>)

# %%
ax.plot(df.x)
# Out:
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000007E72E7C0>

# %%
fig
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
using Markdown

# %%
md"""
|test|table|
|----|-----|
|cont|tents|
"""
# Out:
#   test table
#   –––– –––––
#   cont tents

# %%
@time ax.plot(-df.x)
# Out:
#   0.460678 seconds (464.74 k allocations: 24.301 MiB, 12.41% gc time, 99.56% compilation time)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000061532A60>

# %%
using ProfileView

# %%
@profview plt.subplots();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# .\compiler\typeinfer.jl:996, MethodInstance for Core.Compiler.typeinf_ext_toplevel(::Core.MethodInstance, ::UInt64)

# %% [markdown]
# I right-clicked on a bar (@edit)
